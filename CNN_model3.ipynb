# %%
from keras import layers
from keras import models
from tensorflow.keras.utils import Sequence
import tensorflow as tf
from keras.layers.advanced_activations import LeakyReLU
from keras.optimizers import Adam
import keras.backend as K
import librosa
import librosa.display
import pylab
import matplotlib.pyplot as plt
from matplotlib import figure
import gc
from keras_preprocessing.image import ImageDataGenerator
import os
import pickle as plk
import pandas as pd
import numpy as np

# %%
#check GPU enabled
tf.test.is_gpu_available(
    cuda_only=False, min_cuda_compute_capability=None
)
# Out:
# WARNING:tensorflow:From <ipython-input-2-35f2e13b303a>:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
train_dir = 'E:\\CS224S_final_Project\\data\\melspectrograms\\train\\'
dev_dir = 'E:\\CS224S_final_Project\\data\\melspectrograms\\dev\\'
test_dir= 'E:\\CS224S_final_Project\\data\\melspectrograms\\test\\'

# %%
example = np.load("E:\\CS224S_final_Project\\data\\melspectrograms\\train\\303_0.npy", allow_pickle=True)
input_dim = example[0].shape
print("input dim:", input_dim)

train_index_to_file = {}
idx = 0
for file in os.listdir(train_dir):
    train_index_to_file[idx] = file
    idx += 1
    
dev_index_to_file = {}
idx = 0
for file in os.listdir(dev_dir):
    dev_index_to_file[idx] = file
    idx += 1
    
test_index_to_file = {}
idx = 0
for file in os.listdir(test_dir):
    test_index_to_file[idx] = file
    idx += 1
    
train_idx = np.array(list(train_index_to_file.keys()))
dev_idx = np.array(list(dev_index_to_file.keys()))
test_idx = np.array(list(test_index_to_file.keys()))
print(train_idx.shape, dev_idx.shape)
# Out:
# input dim: (40, 646)
# (3037,) (1154,)

# %%
class MelSpectDataGen(Sequence):
    """
    Generates a dataset of log melspectrograms
    """
    def __init__(self, idx, mel_path, idx_to_file,
                 to_fit=True, batch_size=8, dim=input_dim,
                 shuffle=True):
        self.idx = idx
        self.mel_path = mel_path
        self.idx_to_file = idx_to_file
        self.to_fit = to_fit
        self.batch_size = batch_size
        self.dim = dim
        self.shuffle = shuffle
        self.on_epoch_end()
        
    def __len__(self):
        """
        numbers of batches per epoch
        """
        return int(np.floor(len(self.idx) / self.batch_size))
    
    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.idx)
    
    def __getitem__(self, index):
        """
        returns one batch of data
        """
        idx = self.idx[index * self.batch_size : (index + 1) * self.batch_size]
        files = [self.idx_to_file[i] for i in idx]
        x, y = self.get_data_from_files(files)
        
        if self.to_fit:
            return x, y
        else:
            return x
    
    def get_data_from_files(self, files):
        x = np.empty((self.batch_size, *self.dim))
        y = np.empty((self.batch_size, 1))
        
        for i, file in enumerate(files):
            path = os.path.join(self.mel_path, file)
            data = np.load(path, allow_pickle=True)
            x[i,] = self.process_x(data[0])
            y[i,] = data[1]
        
        return x, y
    
    def process_x(self, x):
        #new_x = np.zeros((x.shape[0], x.shape[1]))
        #new_x[:x.shape[0],] = x 

        return x # np.expand_dims(new_x, 2) # create channel size 1

# %%
# create generators
train_gen = MelSpectDataGen(train_idx, train_dir, train_index_to_file)
dev_gen = MelSpectDataGen(dev_idx, dev_dir, dev_index_to_file)
test_gen = MelSpectDataGen(test_idx, test_dir, test_index_to_file)

# %%
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.models import Sequential, Model
from keras.layers import Conv1D, MaxPooling1D, LSTM
from keras import regularizers, optimizers

model = Sequential()
model.add(BatchNormalization(input_shape=input_dim))
model.add(LSTM(500))
model.add(Dense(1, ))
model.compile(optimizers.RMSprop(lr=0.00001, decay=1e-6),loss="binary_crossentropy",metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 40, 646)           2584
# _________________________________________________________________
# lstm (LSTM)                  (None, 500)               2294000
# _________________________________________________________________
# dense (Dense)                (None, 1)                 501
# =================================================================
# Total params: 2,297,085
# Trainable params: 2,295,793
# Non-trainable params: 1,292
# _________________________________________________________________

# %%
#Fitting keras model, no test gen for now
checkpoint_dir = "E:\\CS224S_final_Project"
checkpoint_path = os.path.join(checkpoint_dir, "cnn_1d_max_pool")
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

#STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
history = model.fit_generator(generator=train_gen,
                    validation_data=dev_gen,
                    epochs=100,
                    callbacks=[cp_callback])
model.evaluate_generator(generator=dev_gen)
# Out:
# Epoch 1/100
# C:\Users\lukes\anaconda3\envs\224s_proj\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 379/379 [==============================] - 7s 13ms/step - loss: 3.0355 - accuracy: 0.7007 - val_loss: 0.7394 - val_accuracy: 0.5295
#
# Epoch 00001: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 2/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.6466 - accuracy: 0.6985 - val_loss: 0.7737 - val_accuracy: 0.5582
#
# Epoch 00002: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 3/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.6083 - accuracy: 0.7142 - val_loss: 0.7432 - val_accuracy: 0.5460
#
# Epoch 00003: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 4/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.5941 - accuracy: 0.7194 - val_loss: 0.7624 - val_accuracy: 0.5599
#
# Epoch 00004: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 5/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.5962 - accuracy: 0.7387 - val_loss: 0.7558 - val_accuracy: 0.5399
#
# Epoch 00005: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 6/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.5770 - accuracy: 0.7471 - val_loss: 0.7334 - val_accuracy: 0.5339
#
# Epoch 00006: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 7/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.6150 - accuracy: 0.7207 - val_loss: 1.1450 - val_accuracy: 0.5929
#
# Epoch 00007: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 8/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.5573 - accuracy: 0.7507 - val_loss: 0.7441 - val_accuracy: 0.5425
#
# Epoch 00008: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 9/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.6213 - accuracy: 0.7398 - val_loss: 0.8171 - val_accuracy: 0.5616
#
# Epoch 00009: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 10/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.5487 - accuracy: 0.7611 - val_loss: 0.7319 - val_accuracy: 0.5564
#
# Epoch 00010: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 11/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.5714 - accuracy: 0.7274 - val_loss: 0.8140 - val_accuracy: 0.5608
#
# Epoch 00011: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 12/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.5639 - accuracy: 0.7498 - val_loss: 0.7898 - val_accuracy: 0.5582
#
# Epoch 00012: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 13/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.5235 - accuracy: 0.7539 - val_loss: 0.7536 - val_accuracy: 0.5495
#
# Epoch 00013: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 14/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.5331 - accuracy: 0.7599 - val_loss: 0.8417 - val_accuracy: 0.5043
#
# Epoch 00014: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 15/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.5308 - accuracy: 0.7395 - val_loss: 0.8736 - val_accuracy: 0.5087
#
# Epoch 00015: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 16/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.5685 - accuracy: 0.7714 - val_loss: 1.0005 - val_accuracy: 0.5434
#
# Epoch 00016: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 17/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.5222 - accuracy: 0.7774 - val_loss: 1.4631 - val_accuracy: 0.5443
#
# Epoch 00017: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 18/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.4916 - accuracy: 0.7938 - val_loss: 1.2210 - val_accuracy: 0.5477
#
# Epoch 00018: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 19/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.5585 - accuracy: 0.7811 - val_loss: 1.5119 - val_accuracy: 0.5304
#
# Epoch 00019: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 20/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.5238 - accuracy: 0.7958 - val_loss: 1.0904 - val_accuracy: 0.5295
#
# Epoch 00020: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 21/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.4752 - accuracy: 0.8003 - val_loss: 2.7248 - val_accuracy: 0.5660
#
# Epoch 00021: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 22/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.5641 - accuracy: 0.7955 - val_loss: 1.2174 - val_accuracy: 0.4939
#
# Epoch 00022: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 23/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.5138 - accuracy: 0.8126 - val_loss: 1.3594 - val_accuracy: 0.4809
#
# Epoch 00023: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 24/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.4427 - accuracy: 0.8200 - val_loss: 3.5701 - val_accuracy: 0.5573
#
# Epoch 00024: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 25/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.5459 - accuracy: 0.8145 - val_loss: 3.1357 - val_accuracy: 0.5451
#
# Epoch 00025: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 26/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.4853 - accuracy: 0.8282 - val_loss: 2.7230 - val_accuracy: 0.5408
#
# Epoch 00026: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 27/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.5123 - accuracy: 0.8386 - val_loss: 2.6079 - val_accuracy: 0.5451
#
# Epoch 00027: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 28/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.4800 - accuracy: 0.8561 - val_loss: 3.2644 - val_accuracy: 0.5521
#
# Epoch 00028: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 29/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.3840 - accuracy: 0.8561 - val_loss: 3.1924 - val_accuracy: 0.5538
#
# Epoch 00029: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 30/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.3441 - accuracy: 0.8689 - val_loss: 2.6628 - val_accuracy: 0.5330
#
# Epoch 00030: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 31/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.4384 - accuracy: 0.8885 - val_loss: 3.2545 - val_accuracy: 0.5434
#
# Epoch 00031: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 32/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.3426 - accuracy: 0.8916 - val_loss: 3.3377 - val_accuracy: 0.5503
#
# Epoch 00032: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 33/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.3111 - accuracy: 0.9086 - val_loss: 3.2794 - val_accuracy: 0.5260
#
# Epoch 00033: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 34/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.3233 - accuracy: 0.9094 - val_loss: 4.8761 - val_accuracy: 0.5538
#
# Epoch 00034: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 35/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.3185 - accuracy: 0.9240 - val_loss: 3.8912 - val_accuracy: 0.5269
#
# Epoch 00035: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 36/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.2909 - accuracy: 0.9292 - val_loss: 4.1370 - val_accuracy: 0.5269
#
# Epoch 00036: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 37/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.2612 - accuracy: 0.9425 - val_loss: 4.6595 - val_accuracy: 0.5365
#
# Epoch 00037: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 38/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.3115 - accuracy: 0.9446 - val_loss: 4.0477 - val_accuracy: 0.5295
#
# Epoch 00038: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 39/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.1931 - accuracy: 0.9587 - val_loss: 4.3148 - val_accuracy: 0.5347
#
# Epoch 00039: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 40/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.2253 - accuracy: 0.9505 - val_loss: 4.4379 - val_accuracy: 0.5399
#
# Epoch 00040: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 41/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.1751 - accuracy: 0.9638 - val_loss: 4.4358 - val_accuracy: 0.5521
#
# Epoch 00041: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 42/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.2084 - accuracy: 0.9710 - val_loss: 4.7200 - val_accuracy: 0.5382
#
# Epoch 00042: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 43/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.1528 - accuracy: 0.9699 - val_loss: 4.7176 - val_accuracy: 0.5382
#
# Epoch 00043: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 44/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.1952 - accuracy: 0.9751 - val_loss: 5.3966 - val_accuracy: 0.5512
#
# Epoch 00044: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 45/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.1046 - accuracy: 0.9727 - val_loss: 4.7751 - val_accuracy: 0.5477
#
# Epoch 00045: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 46/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.1303 - accuracy: 0.9763 - val_loss: 4.8938 - val_accuracy: 0.5391
#
# Epoch 00046: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 47/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.1086 - accuracy: 0.9826 - val_loss: 4.9323 - val_accuracy: 0.5451
#
# Epoch 00047: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 48/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0987 - accuracy: 0.9857 - val_loss: 4.7162 - val_accuracy: 0.5339
#
# Epoch 00048: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 49/100
# 379/379 [==============================] - 4s 11ms/step - loss: 0.0849 - accuracy: 0.9851 - val_loss: 5.0139 - val_accuracy: 0.5330
#
# Epoch 00049: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 50/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.1828 - accuracy: 0.9802 - val_loss: 5.0051 - val_accuracy: 0.5339
#
# Epoch 00050: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 51/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.1335 - accuracy: 0.9853 - val_loss: 4.9623 - val_accuracy: 0.5538
#
# Epoch 00051: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 52/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0754 - accuracy: 0.9856 - val_loss: 5.1619 - val_accuracy: 0.5443
#
# Epoch 00052: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 53/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0926 - accuracy: 0.9832 - val_loss: 5.2381 - val_accuracy: 0.5321
#
# Epoch 00053: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 54/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.1015 - accuracy: 0.9842 - val_loss: 5.5762 - val_accuracy: 0.5417
#
# Epoch 00054: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 55/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0961 - accuracy: 0.9862 - val_loss: 5.3167 - val_accuracy: 0.5443
#
# Epoch 00055: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 56/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0966 - accuracy: 0.9896 - val_loss: 5.1094 - val_accuracy: 0.5486
#
# Epoch 00056: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 57/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0622 - accuracy: 0.9904 - val_loss: 5.4051 - val_accuracy: 0.5599
#
# Epoch 00057: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 58/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0543 - accuracy: 0.9946 - val_loss: 5.3576 - val_accuracy: 0.5469
#
# Epoch 00058: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 59/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0773 - accuracy: 0.9891 - val_loss: 5.1837 - val_accuracy: 0.5503
#
# Epoch 00059: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 60/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.1176 - accuracy: 0.9875 - val_loss: 5.3723 - val_accuracy: 0.5469
#
# Epoch 00060: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 61/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0965 - accuracy: 0.9882 - val_loss: 5.2703 - val_accuracy: 0.5521
#
# Epoch 00061: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 62/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0886 - accuracy: 0.9874 - val_loss: 5.3192 - val_accuracy: 0.5512
#
# Epoch 00062: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 63/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0598 - accuracy: 0.9920 - val_loss: 5.5709 - val_accuracy: 0.5547
#
# Epoch 00063: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 64/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0743 - accuracy: 0.9905 - val_loss: 5.5999 - val_accuracy: 0.5642
#
# Epoch 00064: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 65/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0912 - accuracy: 0.9927 - val_loss: 5.2720 - val_accuracy: 0.5712
#
# Epoch 00065: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 66/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0819 - accuracy: 0.9925 - val_loss: 5.6959 - val_accuracy: 0.5521
#
# Epoch 00066: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 67/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0570 - accuracy: 0.9919 - val_loss: 5.4748 - val_accuracy: 0.5573
#
# Epoch 00067: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 68/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0842 - accuracy: 0.9919 - val_loss: 5.6719 - val_accuracy: 0.5382
#
# Epoch 00068: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 69/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0685 - accuracy: 0.9924 - val_loss: 5.6621 - val_accuracy: 0.5286
#
# Epoch 00069: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 70/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.1176 - accuracy: 0.9863 - val_loss: 5.6445 - val_accuracy: 0.5495
#
# Epoch 00070: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 71/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0734 - accuracy: 0.9928 - val_loss: 5.5691 - val_accuracy: 0.5590
#
# Epoch 00071: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 72/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0729 - accuracy: 0.9927 - val_loss: 5.4660 - val_accuracy: 0.5477
#
# Epoch 00072: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 73/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0755 - accuracy: 0.9897 - val_loss: 5.6971 - val_accuracy: 0.5582
#
# Epoch 00073: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 74/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0804 - accuracy: 0.9941 - val_loss: 5.5578 - val_accuracy: 0.5590
#
# Epoch 00074: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 75/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0529 - accuracy: 0.9952 - val_loss: 5.6785 - val_accuracy: 0.5347
#
# Epoch 00075: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 76/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0871 - accuracy: 0.9918 - val_loss: 5.7444 - val_accuracy: 0.5269
#
# Epoch 00076: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 77/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0596 - accuracy: 0.9931 - val_loss: 5.6360 - val_accuracy: 0.5434
#
# Epoch 00077: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 78/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0759 - accuracy: 0.9935 - val_loss: 5.7192 - val_accuracy: 0.5738
#
# Epoch 00078: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 79/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.1099 - accuracy: 0.9897 - val_loss: 5.5965 - val_accuracy: 0.5417
#
# Epoch 00079: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 80/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.1185 - accuracy: 0.9889 - val_loss: 5.6761 - val_accuracy: 0.5651
#
# Epoch 00080: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 81/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0558 - accuracy: 0.9921 - val_loss: 5.6951 - val_accuracy: 0.5434
#
# Epoch 00081: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 82/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0827 - accuracy: 0.9916 - val_loss: 5.8544 - val_accuracy: 0.5486
#
# Epoch 00082: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 83/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0509 - accuracy: 0.9942 - val_loss: 5.8094 - val_accuracy: 0.5530
#
# Epoch 00083: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 84/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0698 - accuracy: 0.9944 - val_loss: 5.7069 - val_accuracy: 0.5234
#
# Epoch 00084: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 85/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.1030 - accuracy: 0.9934 - val_loss: 5.7776 - val_accuracy: 0.5564
#
# Epoch 00085: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 86/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0712 - accuracy: 0.9933 - val_loss: 5.7451 - val_accuracy: 0.5538
#
# Epoch 00086: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 87/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0427 - accuracy: 0.9966 - val_loss: 5.7694 - val_accuracy: 0.5521
#
# Epoch 00087: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 88/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0529 - accuracy: 0.9947 - val_loss: 5.7245 - val_accuracy: 0.5642
#
# Epoch 00088: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 89/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0928 - accuracy: 0.9922 - val_loss: 5.5198 - val_accuracy: 0.5616
#
# Epoch 00089: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 90/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0527 - accuracy: 0.9938 - val_loss: 5.7774 - val_accuracy: 0.5339
#
# Epoch 00090: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 91/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0642 - accuracy: 0.9926 - val_loss: 5.6514 - val_accuracy: 0.5503
#
# Epoch 00091: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 92/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0373 - accuracy: 0.9944 - val_loss: 5.8329 - val_accuracy: 0.5503
#
# Epoch 00092: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 93/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0532 - accuracy: 0.9949 - val_loss: 5.9164 - val_accuracy: 0.5278
#
# Epoch 00093: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 94/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0424 - accuracy: 0.9952 - val_loss: 5.6795 - val_accuracy: 0.5503
#
# Epoch 00094: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 95/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0640 - accuracy: 0.9945 - val_loss: 5.7827 - val_accuracy: 0.5547
#
# Epoch 00095: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 96/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0373 - accuracy: 0.9971 - val_loss: 5.6245 - val_accuracy: 0.5590
#
# Epoch 00096: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 97/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0533 - accuracy: 0.9948 - val_loss: 5.6394 - val_accuracy: 0.5538
#
# Epoch 00097: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 98/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.1037 - accuracy: 0.9929 - val_loss: 5.7083 - val_accuracy: 0.5608
#
# Epoch 00098: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 99/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0523 - accuracy: 0.9952 - val_loss: 5.7570 - val_accuracy: 0.5434
#
# Epoch 00099: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# Epoch 100/100
# 379/379 [==============================] - 4s 10ms/step - loss: 0.0649 - accuracy: 0.9940 - val_loss: 5.8494 - val_accuracy: 0.5425
#
# Epoch 00100: saving model to E:\CS224S_final_Project\cnn_1d_max_pool
# C:\Users\lukes\anaconda3\envs\224s_proj\lib\site-packages\tensorflow\python\keras\engine\training.py:1877: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# [5.862860679626465, 0.5416666865348816]

# %%
model.evaluate_generator(generator=test_gen)
# Out:
# [4.607485771179199, 0.6129441857337952]

# %%
history.history
# Out:
# {'loss': [0.5970097184181213,
#   0.5864580869674683,
#   0.5733625292778015,
#   0.5593507289886475,
#   0.5499074459075928,
#   0.529107928276062,
#   0.5039184093475342,
#   0.49000266194343567,
#   0.4611984193325043,
#   0.4361407458782196,
#   0.4101009964942932,
#   0.3861428201198578,
#   0.3670750558376312,
#   0.3522728979587555,
#   0.3325035870075226,
#   0.3121224343776703,
#   0.2907268702983856,
#   0.2930213212966919,
#   0.2721068859100342,
#   0.2542506158351898,
#   0.2511141002178192,
#   0.2314685732126236,
#   0.22735288739204407,
#   0.22089965641498566,
#   0.20902900397777557,
#   0.1775413602590561,
#   0.18083719909191132,
#   0.1746797114610672,
#   0.17320701479911804,
#   0.15977928042411804],
#  'accuracy': [0.7194675803184509,
#   0.7171381115913391,
#   0.7174708843231201,
#   0.720798671245575,
#   0.728723406791687,
#   0.7400998473167419,
#   0.7527454495429993,
#   0.7650582194328308,
#   0.7763727307319641,
#   0.7946755290031433,
#   0.8053244352340698,
#   0.8282861709594727,
#   0.8296173214912415,
#   0.841930091381073,
#   0.8552412390708923,
#   0.8625624179840088,
#   0.881863534450531,
#   0.8752079606056213,
#   0.8945091366767883,
#   0.8935108184814453,
#   0.8951746821403503,
#   0.9104825258255005,
#   0.9044924974441528,
#   0.9148086309432983,
#   0.9151414036750793,
#   0.9347753524780273,
#   0.9291181564331055,
#   0.9361065030097961,
#   0.9357737302780151,
#   0.941763699054718],
#  'val_loss': [0.6879515647888184,
#   0.7647912502288818,
#   0.6751869320869446,
#   0.7056582570075989,
#   0.7061577439308167,
#   0.7124395966529846,
#   0.824228048324585,
#   1.0081534385681152,
#   0.9977524876594543,
#   0.8271703124046326,
#   1.0211727619171143,
#   1.04707932472229,
#   1.245517611503601,
#   1.1087685823440552,
#   1.2532625198364258,
#   1.0716782808303833,
#   1.6802115440368652,
#   1.4017770290374756,
#   1.525696039199829,
#   1.5348581075668335,
#   1.7046139240264893,
#   1.4372482299804688,
#   1.9565355777740479,
#   1.7625303268432617,
#   1.8706626892089844,
#   2.0044853687286377,
#   1.8493989706039429,
#   1.9654873609542847,
#   1.703619122505188,
#   1.4613393545150757],
#  'val_accuracy': [0.5980902910232544,
#   0.5980902910232544,
#   0.5972222089767456,
#   0.5963541865348816,
#   0.5642361044883728,
#   0.5078125,
#   0.484375,
#   0.5295138955116272,
#   0.5251736044883728,
#   0.4869791567325592,
#   0.5130208134651184,
#   0.484375,
#   0.5199652910232544,
#   0.5138888955116272,
#   0.4756944477558136,
#   0.4600694477558136,
#   0.5269097089767456,
#   0.4904513955116272,
#   0.5182291865348816,
#   0.4131944477558136,
#   0.5199652910232544,
#   0.4756944477558136,
#   0.4600694477558136,
#   0.4921875,
#   0.4505208432674408,
#   0.5355902910232544,
#   0.5486111044883728,
#   0.5234375,
#   0.4635416567325592,
#   0.4609375]}

# %%
output = model.evaluate_generator(generator=valid_generator, steps=STEP_SIZE_VALID)

# %%
history.history['val_accuracy']
# Out:
# [0.5980902910232544,
#  0.5980902910232544,
#  0.5972222089767456,
#  0.5963541865348816,
#  0.5642361044883728,
#  0.5078125,
#  0.484375,
#  0.5295138955116272,
#  0.5251736044883728,
#  0.4869791567325592,
#  0.5130208134651184,
#  0.484375,
#  0.5199652910232544,
#  0.5138888955116272,
#  0.4756944477558136,
#  0.4600694477558136,
#  0.5269097089767456,
#  0.4904513955116272,
#  0.5182291865348816,
#  0.4131944477558136,
#  0.5199652910232544,
#  0.4756944477558136,
#  0.4600694477558136,
#  0.4921875,
#  0.4505208432674408,
#  0.5355902910232544,
#  0.5486111044883728,
#  0.5234375,
#  0.4635416567325592,
#  0.4609375]

# %%
output
# Out:
# [1.459011435508728, 0.4618055522441864]

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
history.history
# Out:
# {'loss': [0.5970097184181213,
#   0.5864580869674683,
#   0.5733625292778015,
#   0.5593507289886475,
#   0.5499074459075928,
#   0.529107928276062,
#   0.5039184093475342,
#   0.49000266194343567,
#   0.4611984193325043,
#   0.4361407458782196,
#   0.4101009964942932,
#   0.3861428201198578,
#   0.3670750558376312,
#   0.3522728979587555,
#   0.3325035870075226,
#   0.3121224343776703,
#   0.2907268702983856,
#   0.2930213212966919,
#   0.2721068859100342,
#   0.2542506158351898,
#   0.2511141002178192,
#   0.2314685732126236,
#   0.22735288739204407,
#   0.22089965641498566,
#   0.20902900397777557,
#   0.1775413602590561,
#   0.18083719909191132,
#   0.1746797114610672,
#   0.17320701479911804,
#   0.15977928042411804],
#  'accuracy': [0.7194675803184509,
#   0.7171381115913391,
#   0.7174708843231201,
#   0.720798671245575,
#   0.728723406791687,
#   0.7400998473167419,
#   0.7527454495429993,
#   0.7650582194328308,
#   0.7763727307319641,
#   0.7946755290031433,
#   0.8053244352340698,
#   0.8282861709594727,
#   0.8296173214912415,
#   0.841930091381073,
#   0.8552412390708923,
#   0.8625624179840088,
#   0.881863534450531,
#   0.8752079606056213,
#   0.8945091366767883,
#   0.8935108184814453,
#   0.8951746821403503,
#   0.9104825258255005,
#   0.9044924974441528,
#   0.9148086309432983,
#   0.9151414036750793,
#   0.9347753524780273,
#   0.9291181564331055,
#   0.9361065030097961,
#   0.9357737302780151,
#   0.941763699054718],
#  'val_loss': [0.6879515647888184,
#   0.7647912502288818,
#   0.6751869320869446,
#   0.7056582570075989,
#   0.7061577439308167,
#   0.7124395966529846,
#   0.824228048324585,
#   1.0081534385681152,
#   0.9977524876594543,
#   0.8271703124046326,
#   1.0211727619171143,
#   1.04707932472229,
#   1.245517611503601,
#   1.1087685823440552,
#   1.2532625198364258,
#   1.0716782808303833,
#   1.6802115440368652,
#   1.4017770290374756,
#   1.525696039199829,
#   1.5348581075668335,
#   1.7046139240264893,
#   1.4372482299804688,
#   1.9565355777740479,
#   1.7625303268432617,
#   1.8706626892089844,
#   2.0044853687286377,
#   1.8493989706039429,
#   1.9654873609542847,
#   1.703619122505188,
#   1.4613393545150757],
#  'val_accuracy': [0.5980902910232544,
#   0.5980902910232544,
#   0.5972222089767456,
#   0.5963541865348816,
#   0.5642361044883728,
#   0.5078125,
#   0.484375,
#   0.5295138955116272,
#   0.5251736044883728,
#   0.4869791567325592,
#   0.5130208134651184,
#   0.484375,
#   0.5199652910232544,
#   0.5138888955116272,
#   0.4756944477558136,
#   0.4600694477558136,
#   0.5269097089767456,
#   0.4904513955116272,
#   0.5182291865348816,
#   0.4131944477558136,
#   0.5199652910232544,
#   0.4756944477558136,
#   0.4600694477558136,
#   0.4921875,
#   0.4505208432674408,
#   0.5355902910232544,
#   0.5486111044883728,
#   0.5234375,
#   0.4635416567325592,
#   0.4609375]}
